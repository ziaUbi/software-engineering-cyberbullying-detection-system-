# %%
import csv

# ===============================
# 1) Leggi END dal file di testo
# ===============================
dev_end_times = []

with open("timestamp_log_0.txt", "r") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        timestamp, system, status = line.split(",")

        if system == "Development System" and status == "end":
            dev_end_times.append(float(timestamp))

# ======================================
# 2) Leggi START dal file CSV (con header)
# ======================================
classifier_start_times = []

with open("development_log_0.csv", newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        if row["status"] == "start":
            classifier_start_times.append(float(row["timestamp"]))

# =========================
# 3) Calcolo differenze
# =========================
n = min(len(dev_end_times), len(classifier_start_times))

if n == 0:
    raise ValueError("Nessuna coppia valida trovata")

differences = [
    dev_end_times[i] - classifier_start_times[i]
    for i in range(n)
]

import matplotlib.pyplot as plt
plt.plot(range(1, len(differences) + 1), differences, label="Time Differences")
plt.xlabel("Pair Index")
plt.ylabel("Time Difference (seconds)")
plt.title("Time Differences Between Development System End and Classifier Start")
plt.legend()
plt.show()

average_difference = sum(differences) / n

# =========================
# 4) Output
# =========================
print("Differenze (secondi):")
for i, d in enumerate(differences, start=1):
    print(f"{i}: {d:.6f}")

print(f"\nMedia differenze: {average_difference:.6f} s")
# Out:
# Differenze (secondi):
# 1: 140.489551
# 2: 147.729797
# 3: 159.788932
# 4: 206.123377
# 5: 222.616115
#
# Media differenze: 175.349554 s

# %%
import csv

# ===============================
# 1) Leggi END dal file di testo
# ===============================
dev_end_times = []

with open("timestamp_log_1.txt", "r") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        timestamp, system, status = line.split(",")

        if system == "Development System" and status == "end":
            dev_end_times.append(float(timestamp))

# ======================================
# 2) Leggi START dal file CSV (con header)
# ======================================
classifier_start_times = []

with open("development_log_1.csv", newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        if row["status"] == "start":
            classifier_start_times.append(float(row["timestamp"]))

# =========================
# 3) Calcolo differenze
# =========================
n = min(len(dev_end_times), len(classifier_start_times))

if n == 0:
    raise ValueError("Nessuna coppia valida trovata")

differences = [
    dev_end_times[i] - classifier_start_times[i]
    for i in range(n)
]

import matplotlib.pyplot as plt
plt.plot(range(1, len(differences) + 1), differences, label="Time Differences")
plt.xlabel("Pair Index")
plt.ylabel("Time Difference (seconds)")
plt.title("Time Differences Between Development System End and Classifier Start")
plt.legend()
plt.show()

average_difference = sum(differences) / n

# =========================
# 4) Output
# =========================
print("Differenze (secondi):")
for i, d in enumerate(differences, start=1):
    print(f"{i}: {d:.6f}")

print(f"\nMedia differenze: {average_difference:.6f} s")
# Out:
# Differenze (secondi):
# 1: 150.603509
# 2: 156.208574
# 3: 158.132000
# 4: 170.622680
# 5: 174.439210
# 6: 153.521807
# 7: 173.072992
# 8: 200.784851
# 9: 216.771966
# 10: 228.818679
#
# Media differenze: 178.297627 s

# %%
import csv

# ===============================
# 1) Leggi END dal file di testo
# ===============================
dev_end_times = []

with open("timestamp_log_2.txt", "r") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        timestamp, system, status = line.split(",")

        if system == "Development System" and status == "end":
            dev_end_times.append(float(timestamp))

# ======================================
# 2) Leggi START dal file CSV (con header)
# ======================================
classifier_start_times = []

with open("development_log_2.csv", newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        if row["status"] == "start":
            classifier_start_times.append(float(row["timestamp"]))

# =========================
# 3) Calcolo differenze
# =========================
n = min(len(dev_end_times), len(classifier_start_times))

if n == 0:
    raise ValueError("Nessuna coppia valida trovata")

differences = [
    dev_end_times[i] - classifier_start_times[i]
    for i in range(n)
]

import matplotlib.pyplot as plt
plt.plot(range(1, len(differences) + 1), differences, label="Time Differences")
plt.xlabel("Pair Index")
plt.ylabel("Time Difference (seconds)")
plt.title("Time Differences Between Development System End and Classifier Start")
plt.legend()
plt.show()

average_difference = sum(differences) / n

# =========================
# 4) Output
# =========================
print("Differenze (secondi):")
for i, d in enumerate(differences, start=1):
    print(f"{i}: {d:.6f}")

print(f"\nMedia differenze: {average_difference:.6f} s")
# Out:
# Differenze (secondi):
# 1: 174.665509
# 2: 150.367174
# 3: 156.319986
# 4: 124.903508
# 5: 144.369118
# 6: 163.891231
# 7: 158.016395
# 8: 160.752918
# 9: 165.214228
# 10: 161.587312
# 11: 169.806892
# 12: 259.342266
# 13: 352.844115
# 14: 380.464783
# 15: 424.228842
# 16: 448.115637
# 17: 469.728316
# 18: 479.843214
# 19: 499.806926
# 20: 530.128084
# 21: 547.285249
# 22: 583.065286
# 23: 613.332836
# 24: 629.034053
# 25: 651.376063
# 26: 679.627691
# 27: 634.262743
# 28: 654.990834
# 29: 688.890821
# 30: 699.103576
# 31: 724.815469
# 32: 740.818794
# 33: 741.908378
# 34: 754.009868
# 35: 762.810378
# 36: 777.771709
# 37: 795.919751
# 38: 793.304960
# 39: 792.489350
# 40: 798.655892
# 41: 788.695932
# 42: 807.434177
# 43: 785.792432
# 44: 786.934984
# 45: 796.344669
# 46: 814.784563
# 47: 829.478265
# 48: 922.733627
# 49: 939.464128
# 50: 956.673225
#
# Media differenze: 561.324123 s
